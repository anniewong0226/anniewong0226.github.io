# %%
import requests
import pandas as pd

# %%
from datetime import datetime, timedelta
import time

# %%
import json
import os
from typing import List, Dict, Optional

# %%
import pandas as pd
import numpy as np
import glob
import os
from datetime import datetime
import re

INPUT_DIR = '/Users/annie_lok_yan_wong/Downloads/CFE%/' 
OUTPUT_DIR = '/Users/annie_lok_yan_wong/Downloads/CFE%/merged_output'  
os.makedirs(OUTPUT_DIR, exist_ok=True)

COLUMNS_TO_KEEP = {
    'Datetime (UTC)': 'timestamp',
    'Zone id': 'zone',
    'Country': 'country',
    'Carbon-free energy percentage (CFE%)': 'carbon_free_pct',
    'Renewable energy percentage (RE%)': 'renewable_pct',
    'Carbon intensity gCO₂eq/kWh (direct)': 'carbon_intensity_direct',
    'Carbon intensity gCO₂eq/kWh (Life cycle)': 'carbon_intensity_lifecycle',
    'Data estimated': 'is_estimated'
}

def extract_metadata_from_filename(filename):
    """
    Extract zone and year from filename.
    Example: 'snapshots_2025-07-03_DK-2023-hourly.csv' -> ('DK', 2023)
    """
    basename = os.path.basename(filename)
    
    # Pattern: zone-year
    match = re.search(r'_([A-Z]{2})-(\d{4})-', basename)
    if match:
        zone = match.group(1)
        year = int(match.group(2))
        return zone, year
    
    return None, None


def load_and_process_file(filepath):
   
    try:
        # Load CSV
        df = pd.read_csv(filepath)
        
        # Get metadata from filename
        zone_from_file, year_from_file = extract_metadata_from_filename(filepath)
        
        # Rename columns to standard names
        df = df.rename(columns=COLUMNS_TO_KEEP)
        
        # Keep only columns we want
        cols_present = [col for col in COLUMNS_TO_KEEP.values() if col in df.columns]
        df = df[cols_present]
        
        # Convert timestamp to datetime
        df['timestamp'] = pd.to_datetime(df['timestamp'])
        
        # Extract year from data
        df['year'] = df['timestamp'].dt.year
        
        # Add metadata
        df['source_file'] = os.path.basename(filepath)
        
        # Convert is_estimated to boolean
        if 'is_estimated' in df.columns:
            df['is_estimated'] = df['is_estimated'].map({'true': True, 'false': False, True: True, False: False})
        
        return df, zone_from_file, year_from_file
    
    except Exception as e:
        print(f"Error processing {os.path.basename(filepath)}: {e}")
        return None, None, None

# %%
#Merge all country CSV files into one dataset.
def merge_all_country_files(input_dir, file_pattern='snapshots_*.csv'):
    
    # Find all CSV files
    file_pattern_full = os.path.join(input_dir, file_pattern)
    csv_files = glob.glob(file_pattern_full)
    
    if not csv_files:
        print(f"No files found matching pattern: {file_pattern_full}")
        return None
    
    print(f"Found {len(csv_files)} files to merge")
    
    # Load and process each file
    all_dataframes = []
    file_summaries = []
    
    for i, filepath in enumerate(sorted(csv_files), 1):
        filename = os.path.basename(filepath)
        print(f"\n[{i}/{len(csv_files)}] Processing: {filename}")
        
        df, zone, year = load_and_process_file(filepath)
        
        if df is not None:
            summary = get_data_summary(df)
            print(f"Loaded: {summary['total_rows']} rows")
            print(f"Zone: {df['zone'].iloc[0]}, Year: {df['year'].unique().tolist()}")
            print(f"Date range: {summary['date_range']}")
            print(f"Missing data: {summary['missing_pct']}")
            print(f"Avg carbon-free: {summary['avg_carbon_free']}")
            
            all_dataframes.append(df)
            file_summaries.append({
                'file': filename,
                'zone': zone,
                'year': year,
                **summary
            })
        else:
            print(f"Failed to load")

# %%
#Merge all country CSV files into one dataset.
def merge_all_country_files(input_dir, file_pattern='snapshots_*.csv'):
    
    # Find all CSV files
    file_pattern_full = os.path.join(input_dir, file_pattern)
    csv_files = glob.glob(file_pattern_full)
    
    if not csv_files:
        print(f"No files found matching pattern: {file_pattern_full}")
        return None
    
    print(f"Found {len(csv_files)} files to merge")
    
    # Load and process each file
    all_dataframes = []
    file_summaries = []
    
    for i, filepath in enumerate(sorted(csv_files), 1):
        filename = os.path.basename(filepath)
        print(f"\n[{i}/{len(csv_files)}] Processing: {filename}")
        
        df, zone, year = load_and_process_file(filepath)
        
        if df is not None:
            summary = get_data_summary(df)
            print(f"Loaded: {summary['total_rows']} rows")
            print(f"Zone: {df['zone'].iloc[0]}, Year: {df['year'].unique().tolist()}")
            print(f"Date range: {summary['date_range']}")
            print(f"Missing data: {summary['missing_pct']}")
            print(f"Avg carbon-free: {summary['avg_carbon_free']}")
            
            all_dataframes.append(df)
            file_summaries.append({
                'file': filename,
                'zone': zone,
                'year': year,
                **summary
            })
        else:
            print(f"Failed to load")

    
    # Combine all dataframes
    print(f"Merging {len(all_dataframes)} dataframes...")
    merged_df = pd.concat(all_dataframes, ignore_index=True)
    
    # Sort by zone and timestamp
    merged_df = merged_df.sort_values(['zone', 'timestamp']).reset_index(drop=True)
    
    # Remove duplicates (if any)
    duplicates_before = len(merged_df)
    merged_df = merged_df.drop_duplicates(subset=['zone', 'timestamp'])
    duplicates_removed = duplicates_before - len(merged_df)
    
    if duplicates_removed > 0:
        print(f"Removed {duplicates_removed} duplicate rows")
    
    print(f"Merged dataset: {len(merged_df)} rows")
    
    # Summary by country
    print("\n" + "=" * 70)
    print("SUMMARY BY COUNTRY")
    print("=" * 70)
    
    country_summary = merged_df.groupby('zone').agg({
        'timestamp': ['min', 'max', 'count'],
        'carbon_free_pct': ['mean', 'std'],
        'country': 'first'
    }).round(2)
    
    print(country_summary.to_string())
    
    # Save summary report
    summary_df = pd.DataFrame(file_summaries)
    summary_path = os.path.join(OUTPUT_DIR, 'merge_summary_report.csv')
    summary_df.to_csv(summary_path, index=False)
    print(f"\n💾 Summary report saved to: {summary_path}")
    
    return merged_df

# %%
def create_wide_format(merged_df):

# Create wide format where each country is a column.
    
    # Pivot carbon-free percentage
    wide_cf = merged_df.pivot(
        index='timestamp',
        columns='zone',
        values='carbon_free_pct'
    )
    
    # Add suffix to column names
    wide_cf.columns = [f'{col}_carbon_free_pct' for col in wide_cf.columns]
    
    print(f" Wide format: {len(wide_cf)} rows × {len(wide_cf.columns)} columns")
    
    return wide_cf


def check_data_quality(merged_df):
    """
    Perform comprehensive data quality checks.
    """
    print("\n🔍 DATA QUALITY CHECKS")
    print("=" * 70)
    
    issues = []
    
    # Check 1: Missing data
    missing_counts = merged_df['carbon_free_pct'].isna().sum()
    missing_pct = (missing_counts / len(merged_df)) * 100
    print(f"Missing carbon-free data: {missing_counts} ({missing_pct:.2f}%)")
    if missing_pct > 5:
        issues.append(f"High missing data: {missing_pct:.2f}%")
    
    # Check 2: Invalid values (should be 0-100)
    invalid = ((merged_df['carbon_free_pct'] < 0) | (merged_df['carbon_free_pct'] > 100)).sum()
    print(f"Invalid values (<0 or >100): {invalid}")
    if invalid > 0:
        issues.append(f"{invalid} invalid percentage values")
    
    # Check 3: Time gaps
    print("\nTime gaps by country:")
    for zone in merged_df['zone'].unique():
        zone_df = merged_df[merged_df['zone'] == zone].sort_values('timestamp')
        time_diffs = zone_df['timestamp'].diff()
        gaps = (time_diffs > pd.Timedelta(hours=1)).sum()
        print(f"  {zone}: {gaps} gaps")
        if gaps > 10:
            issues.append(f"{zone} has {gaps} time gaps")
    
    # Check 4: Date coverage
    print("\nDate coverage by country:")
    coverage = merged_df.groupby('zone')['timestamp'].agg(['min', 'max', 'count'])
    print(coverage)

# %%
def main():
    
    # Step 1: Merge all files
    merged_df = merge_all_country_files(INPUT_DIR)
    
    if merged_df is None:
        return
    
    # Step 2: Save merged dataset
    output_path = os.path.join(OUTPUT_DIR, 'all_countries_merged.csv')
    merged_df.to_csv(output_path, index=False)
    print(f"Merged dataset saved to: {output_path}")
    
    # Step 3: Data quality checks
    check_data_quality(merged_df)
    
    # Step 4: Create wide format (optional)
    wide_df = create_wide_format(merged_df)
    wide_path = os.path.join(OUTPUT_DIR, 'all_countries_wide_format.csv')
    wide_df.to_csv(wide_path)
    print(f"Wide format saved to: {wide_path}")
    
    # Step 5: Final summary
    print("\n" + "=" * 70)
    print("MERGE COMPLETE!")
    print("=" * 70)
    print(f"Total countries: {merged_df['zone'].nunique()}")
    print(f"Total rows: {len(merged_df):,}")
    print(f"Date range: {merged_df['timestamp'].min()} to {merged_df['timestamp'].max()}")
    print(f"\nFiles created:")
    print(f"  1. {output_path}")
    print(f"  2. {wide_path}")
    print(f"  3. {os.path.join(OUTPUT_DIR, 'merge_summary_report.csv')}")
    


if __name__ == "__main__":
        main()
# Out:
# Found 40 files to merge
#
# [1/40] Processing: snapshots_2025-07-03_AT-2023-hourly.csv
# Loaded: 8760 rows
# Zone: AT, Year: [2023]
# Date range: 2023-01-01 00:00:00 to 2023-12-31 23:00:00
# Missing data: 0.00%
# Avg carbon-free: 83.38%
#
# [2/40] Processing: snapshots_2025-07-03_AT-2024-hourly.csv
# Loaded: 8784 rows
# Zone: AT, Year: [2024]
# Date range: 2024-01-01 00:00:00 to 2024-12-31 23:00:00
# Missing data: 0.00%
# Avg carbon-free: 86.98%
#
# [3/40] Processing: snapshots_2025-07-03_BE-2023-hourly.csv
# Loaded: 8760 rows
# Zone: BE, Year: [2023]
# Date range: 2023-01-01 00:00:00 to 2023-12-31 23:00:00
# Missing data: 0.00%
# Avg carbon-free: 73.03%
#
# [4/40] Processing: snapshots_2025-07-03_BE-2024-hourly.csv
# Loaded: 8784 rows
# Zone: BE, Year: [2024]
# Date range: 2024-01-01 00:00:00 to 2024-12-31 23:00:00
# Missing data: 0.00%
# Avg carbon-free: 77.54%
#
# [5/40] Processing: snapshots_2025-07-03_CH-2023-hourly.csv
# Loaded: 8760 rows
# Zone: CH, Year: [2023]
# Date range: 2023-01-01 00:00:00 to 2023-12-31 23:00:00
# Missing data: 0.00%
# Avg carbon-free: 95.47%
#
# [6/40] Processing: snapshots_2025-07-03_CH-2024-hourly.csv
# Loaded: 8784 rows
# Zone: CH, Year: [2024]
# Date range: 2024-01-01 00:00:00 to 2024-12-31 23:00:00
# Missing data: 0.00%
# Avg carbon-free: 97.52%
#
# [7/40] Processing: snapshots_2025-07-03_CZ-2023-hourly.csv
# Loaded: 8760 rows
# Zone: CZ, Year: [2023]
# Date range: 2023-01-01 00:00:00 to 2023-12-31 23:00:00
# Missing data: 0.00%
# Avg carbon-free: 52.78%
#
# [8/40] Processing: snapshots_2025-07-03_CZ-2024-hourly.csv
# Loaded: 8784 rows
# Zone: CZ, Year: [2024]
# Date range: 2024-01-01 00:00:00 to 2024-12-31 23:00:00
# Missing data: 0.00%
# Avg carbon-free: 56.47%
#
# [9/40] Processing: snapshots_2025-07-03_DE-2023-hourly.csv
# Loaded: 8760 rows
# Zone: DE, Year: [2023]
# Date range: 2023-01-01 00:00:00 to 2023-12-31 23:00:00
# Missing data: 0.00%
# Avg carbon-free: 63.14%
#
# [10/40] Processing: snapshots_2025-07-03_DE-2024-hourly.csv
# Loaded: 8784 rows
# Zone: DE, Year: [2024]
# Date range: 2024-01-01 00:00:00 to 2024-12-31 23:00:00
# Missing data: 0.00%
# Avg carbon-free: 65.76%
#
# [11/40] Processing: snapshots_2025-07-03_DK-2023-hourly.csv
# Loaded: 8760 rows
# Zone: DK, Year: [2023]
# Date range: 2023-01-01 00:00:00 to 2023-12-31 23:00:00
# Missing data: 0.00%
# Avg carbon-free: 86.40%
#
# [12/40] Processing: snapshots_2025-07-03_DK-2024-hourly.csv
# Loaded: 8784 rows
# Zone: DK, Year: [2024]
# Date range: 2024-01-01 00:00:00 to 2024-12-31 23:00:00
# Missing data: 0.00%
# Avg carbon-free: 87.44%
#
# [13/40] Processing: snapshots_2025-07-03_ES-2023-hourly.csv
# Loaded: 8760 rows
# Zone: ES, Year: [2023]
# Date range: 2023-01-01 00:00:00 to 2023-12-31 23:00:00
# Missing data: 0.00%
# Avg carbon-free: 76.12%
#
# [14/40] Processing: snapshots_2025-07-03_ES-2024-hourly.csv
# Loaded: 8784 rows
# Zone: ES, Year: [2024]
# Date range: 2024-01-01 00:00:00 to 2024-12-31 23:00:00
# Missing data: 0.00%
# Avg carbon-free: 81.54%
#
# [15/40] Processing: snapshots_2025-07-03_FI-2023-hourly.csv
# Loaded: 8760 rows
# Zone: FI, Year: [2023]
# Date range: 2023-01-01 00:00:00 to 2023-12-31 23:00:00
# Missing data: 0.00%
# Avg carbon-free: 92.32%
#
# [16/40] Processing: snapshots_2025-07-03_FI-2024-hourly.csv
# Loaded: 8784 rows
# Zone: FI, Year: [2024]
# Date range: 2024-01-01 00:00:00 to 2024-12-31 23:00:00
# Missing data: 0.00%
# Avg carbon-free: 93.55%
#
# [17/40] Processing: snapshots_2025-07-03_FR-2023-hourly.csv
# Loaded: 8760 rows
# Zone: FR, Year: [2023]
# Date range: 2023-01-01 00:00:00 to 2023-12-31 23:00:00
# Missing data: 0.00%
# Avg carbon-free: 93.24%
#
# [18/40] Processing: snapshots_2025-07-03_FR-2024-hourly.csv
# Loaded: 8784 rows
# Zone: FR, Year: [2024]
# Date range: 2024-01-01 00:00:00 to 2024-12-31 23:00:00
# Missing data: 0.00%
# Avg carbon-free: 96.39%
#
# [19/40] Processing: snapshots_2025-07-03_GB-2023-hourly.csv
# Loaded: 8760 rows
# Zone: GB, Year: [2023]
# Date range: 2023-01-01 00:00:00 to 2023-12-31 23:00:00
# Missing data: 0.00%
# Avg carbon-free: 65.32%
#
# [20/40] Processing: snapshots_2025-07-03_GB-2024-hourly.csv
# Loaded: 8784 rows
# Zone: GB, Year: [2024]
# Date range: 2024-01-01 00:00:00 to 2024-12-31 23:00:00
# Missing data: 0.00%
# Avg carbon-free: 71.72%
#
# [21/40] Processing: snapshots_2025-07-03_GR-2023-hourly.csv
# Loaded: 8760 rows
# Zone: GR, Year: [2023]
# Date range: 2023-01-01 00:00:00 to 2023-12-31 23:00:00
# Missing data: 0.00%
# Avg carbon-free: 50.84%
#
# [22/40] Processing: snapshots_2025-07-03_GR-2024-hourly.csv
# Loaded: 8784 rows
# Zone: GR, Year: [2024]
# Date range: 2024-01-01 00:00:00 to 2024-12-31 23:00:00
# Missing data: 0.00%
# Avg carbon-free: 50.04%
#
# [23/40] Processing: snapshots_2025-07-03_HU-2023-hourly.csv
# Loaded: 8760 rows
# Zone: HU, Year: [2023]
# Date range: 2023-01-01 00:00:00 to 2023-12-31 23:00:00
# Missing data: 0.00%
# Avg carbon-free: 70.25%
#
# [24/40] Processing: snapshots_2025-07-03_HU-2024-hourly.csv
# Loaded: 8784 rows
# Zone: HU, Year: [2024]
# Date range: 2024-01-01 00:00:00 to 2024-12-31 23:00:00
# Missing data: 0.00%
# Avg carbon-free: 72.73%
#
# [25/40] Processing: snapshots_2025-07-03_IE-2023-hourly.csv
# Loaded: 8760 rows
# Zone: IE, Year: [2023]
# Date range: 2023-01-01 00:00:00 to 2023-12-31 23:00:00
# Missing data: 0.00%
# Avg carbon-free: 43.88%
#
# [26/40] Processing: snapshots_2025-07-03_IE-2024-hourly.csv
# Loaded: 8784 rows
# Zone: IE, Year: [2024]
# Date range: 2024-01-01 00:00:00 to 2024-12-31 23:00:00
# Missing data: 0.00%
# Avg carbon-free: 43.81%
#
# [27/40] Processing: snapshots_2025-07-03_IT-2023-hourly.csv
# Loaded: 8760 rows
# Zone: IT, Year: [2023]
# Date range: 2023-01-01 00:00:00 to 2023-12-31 23:00:00
# Missing data: 0.00%
# Avg carbon-free: 51.70%
#
# [28/40] Processing: snapshots_2025-07-03_IT-2024-hourly.csv
# Loaded: 8784 rows
# Zone: IT, Year: [2024]
# Date range: 2024-01-01 00:00:00 to 2024-12-31 23:00:00
# Missing data: 0.00%
# Avg carbon-free: 57.42%
#
# [29/40] Processing: snapshots_2025-07-03_NL-2023-hourly.csv
# Loaded: 8760 rows
# Zone: NL, Year: [2023]
# Date range: 2023-01-01 00:00:00 to 2023-12-31 23:00:00
# Missing data: 0.00%
# Avg carbon-free: 53.46%
#
# [30/40] Processing: snapshots_2025-07-03_NL-2024-hourly.csv
# Loaded: 8784 rows
# Zone: NL, Year: [2024]
# Date range: 2024-01-01 00:00:00 to 2024-12-31 23:00:00
# Missing data: 0.00%
# Avg carbon-free: 56.10%
#
# [31/40] Processing: snapshots_2025-07-03_NO-2023-hourly.csv
# Loaded: 8760 rows
# Zone: NO, Year: [2023]
# Date range: 2023-01-01 00:00:00 to 2023-12-31 23:00:00
# Missing data: 0.00%
# Avg carbon-free: 98.20%
#
# [32/40] Processing: snapshots_2025-07-03_NO-2024-hourly.csv
# Loaded: 8784 rows
# Zone: NO, Year: [2024]
# Date range: 2024-01-01 00:00:00 to 2024-12-31 23:00:00
# Missing data: 0.00%
# Avg carbon-free: 98.11%
#
# [33/40] Processing: snapshots_2025-07-03_PL-2023-hourly.csv
# Loaded: 8760 rows
# Zone: PL, Year: [2023]
# Date range: 2023-01-01 00:00:00 to 2023-12-31 23:00:00
# Missing data: 0.00%
# Avg carbon-free: 30.92%
#
# [34/40] Processing: snapshots_2025-07-03_PL-2024-hourly.csv
# Loaded: 8784 rows
# Zone: PL, Year: [2024]
# Date range: 2024-01-01 00:00:00 to 2024-12-31 23:00:00
# Missing data: 0.00%
# Avg carbon-free: 32.57%
#
# [35/40] Processing: snapshots_2025-07-03_PT-2023-hourly.csv
# Loaded: 8760 rows
# Zone: PT, Year: [2023]
# Date range: 2023-01-01 00:00:00 to 2023-12-31 23:00:00
# Missing data: 0.00%
# Avg carbon-free: 76.28%
#
# [36/40] Processing: snapshots_2025-07-03_PT-2024-hourly.csv
# Loaded: 8784 rows
# Zone: PT, Year: [2024]
# Date range: 2024-01-01 00:00:00 to 2024-12-31 23:00:00
# Missing data: 0.00%
# Avg carbon-free: 87.15%
#
# [37/40] Processing: snapshots_2025-07-03_RO-2023-hourly.csv
# Loaded: 8760 rows
# Zone: RO, Year: [2023]
# Date range: 2023-01-01 00:00:00 to 2023-12-31 23:00:00
# Missing data: 0.00%
# Avg carbon-free: 68.20%
#
# [38/40] Processing: snapshots_2025-07-03_RO-2024-hourly.csv
# Loaded: 8784 rows
# Zone: RO, Year: [2024]
# Date range: 2024-01-01 00:00:00 to 2024-12-31 23:00:00
# Missing data: 0.00%
# Avg carbon-free: 66.09%
#
# [39/40] Processing: snapshots_2025-07-03_SE-2023-hourly.csv
# Loaded: 8760 rows
# Zone: SE, Year: [2023]
# Date range: 2023-01-01 00:00:00 to 2023-12-31 23:00:00
# Missing data: 0.00%
# Avg carbon-free: 99.53%
#
# [40/40] Processing: snapshots_2025-07-03_SE-2024-hourly.csv
# Loaded: 8784 rows
# Zone: SE, Year: [2024]
# Date range: 2024-01-01 00:00:00 to 2024-12-31 23:00:00
# Missing data: 0.00%
# Avg carbon-free: 99.56%
# Merging 40 dataframes...
# Merged dataset: 350880 rows
#
# ======================================================================
# SUMMARY BY COUNTRY
# ======================================================================
#       timestamp                            carbon_free_pct               country
#             min                 max  count            mean    std          first
# zone
# AT   2023-01-01 2024-12-31 23:00:00  17544           85.19  11.80        Austria
# BE   2023-01-01 2024-12-31 23:00:00  17544           75.29  11.68        Belgium
# CH   2023-01-01 2024-12-31 23:00:00  17544           96.50   4.02    Switzerland
# CZ   2023-01-01 2024-12-31 23:00:00  17544           54.63  10.15        Czechia
# DE   2023-01-01 2024-12-31 23:00:00  17544           64.45  14.54        Germany
# DK   2023-01-01 2024-12-31 23:00:00  17544           86.92   8.03        Denmark
# ES   2023-01-01 2024-12-31 23:00:00  17544           78.83  10.34          Spain
# FI   2023-01-01 2024-12-31 23:00:00  17544           92.93   4.51        Finland
# FR   2023-01-01 2024-12-31 23:00:00  17544           94.82   4.08         France
# GB   2023-01-01 2024-12-31 23:00:00  17544           68.52  15.28  Great Britain
# GR   2023-01-01 2024-12-31 23:00:00  17544           50.44  18.63         Greece
# HU   2023-01-01 2024-12-31 23:00:00  17544           71.49   8.10        Hungary
# IE   2023-01-01 2024-12-31 23:00:00  17544           43.84  20.84        Ireland
# IT   2023-01-01 2024-12-31 23:00:00  17544           54.57  12.20          Italy
# NL   2023-01-01 2024-12-31 23:00:00  17544           54.78  20.70    Netherlands
# NO   2023-01-01 2024-12-31 23:00:00  17544           98.15   0.97         Norway
# PL   2023-01-01 2024-12-31 23:00:00  17544           31.75  12.42         Poland
# PT   2023-01-01 2024-12-31 23:00:00  17544           81.73  13.30       Portugal
# RO   2023-01-01 2024-12-31 23:00:00  17544           67.14   7.36        Romania
# SE   2023-01-01 2024-12-31 23:00:00  17544           99.54   0.72         Sweden
#
# 💾 Summary report saved to: /Users/annie_lok_yan_wong/Downloads/CFE%/merged_output/merge_summary_report.csv
# Merged dataset saved to: /Users/annie_lok_yan_wong/Downloads/CFE%/merged_output/all_countries_merged.csv
#
# 🔍 DATA QUALITY CHECKS
# ======================================================================
# Missing carbon-free data: 0 (0.00%)
# Invalid values (<0 or >100): 0
#
# Time gaps by country:
#   AT: 0 gaps
#   BE: 0 gaps
#   CH: 0 gaps
#   CZ: 0 gaps
#   DE: 0 gaps
#   DK: 0 gaps
#   ES: 0 gaps
#   FI: 0 gaps
#   FR: 0 gaps
#   GB: 0 gaps
#   GR: 0 gaps
#   HU: 0 gaps
#   IE: 0 gaps
#   IT: 0 gaps
#   NL: 0 gaps
#   NO: 0 gaps
#   PL: 0 gaps
#   PT: 0 gaps
#   RO: 0 gaps
#   SE: 0 gaps
#
# Date coverage by country:
#             min                 max  count
# zone
# AT   2023-01-01 2024-12-31 23:00:00  17544
# BE   2023-01-01 2024-12-31 23:00:00  17544
# CH   2023-01-01 2024-12-31 23:00:00  17544
# CZ   2023-01-01 2024-12-31 23:00:00  17544
# DE   2023-01-01 2024-12-31 23:00:00  17544
# DK   2023-01-01 2024-12-31 23:00:00  17544
# ES   2023-01-01 2024-12-31 23:00:00  17544
# FI   2023-01-01 2024-12-31 23:00:00  17544
# FR   2023-01-01 2024-12-31 23:00:00  17544
# GB   2023-01-01 2024-12-31 23:00:00  17544
# GR   2023-01-01 2024-12-31 23:00:00  17544
# HU   2023-01-01 2024-12-31 23:00:00  17544
# IE   2023-01-01 2024-12-31 23:00:00  17544
# IT   2023-01-01 2024-12-31 23:00:00  17544
# NL   2023-01-01 2024-12-31 23:00:00  17544
# NO   2023-01-01 2024-12-31 23:00:00  17544
# PL   2023-01-01 2024-12-31 23:00:00  17544
# PT   2023-01-01 2024-12-31 23:00:00  17544
# RO   2023-01-01 2024-12-31 23:00:00  17544
# SE   2023-01-01 2024-12-31 23:00:00  17544
#  Wide format: 17544 rows × 20 columns
# Wide format saved to: /Users/annie_lok_yan_wong/Downloads/CFE%/merged_output/all_countries_wide_format.csv
#
# ======================================================================
# MERGE COMPLETE!
# ======================================================================
# Total countries: 20
# Total rows: 350,880
# Date range: 2023-01-01 00:00:00 to 2024-12-31 23:00:00
#
# Files created:
#   1. /Users/annie_lok_yan_wong/Downloads/CFE%/merged_output/all_countries_merged.csv
#   2. /Users/annie_lok_yan_wong/Downloads/CFE%/merged_output/all_countries_wide_format.csv
#   3. /Users/annie_lok_yan_wong/Downloads/CFE%/merged_output/merge_summary_report.csv

# %%
import pandas as pd
import numpy as np
import os
import glob

# Paths
CARBON_FREE_DATA = '/Users/annie_lok_yan_wong/Downloads/CFE%/merged_output/all_countries_merged.csv'
PRICING_DIR = '/Users/annie_lok_yan_wong/Downloads/european_wholesale_electricity_price_data_hourly/For_merging'  # Directory with pricing CSV files
OUTPUT_DIR = '/Users/annie_lok_yan_wong/Downloads/european_wholesale_electricity_price_data_hourly/For_merging/final_merged'  # Output directory
os.makedirs(OUTPUT_DIR, exist_ok=True)

# ISO3 to ISO2 mapping (3-letter to 2-letter zone codes)
ISO3_TO_ISO2 = {
    'NLD': 'NL',  
    'DEU': 'DE',  
    'FRA': 'FR',  
    'ESP': 'ES',  
    'ITA': 'IT',  
    'GBR': 'GB',  
    'BEL': 'BE',  
    'POL': 'PL',  
    'AUT': 'AT',  
    'CHE': 'CH',  
    'SWE': 'SE',  
    'NOR': 'NO',  
    'DNK': 'DK',  
    'FIN': 'FI',  
    'PRT': 'PT', 
    'GRC': 'GR', 
    'CZE': 'CZ', 
    'ROU': 'RO', 
    'IRL': 'IE', 
    'HUN': 'HU', 
}

TARGET_YEARS = [2023, 2024]

def load_pricing_file(filepath):
    """
    Load and standardize a pricing CSV file.
    
    Expected columns:
    - Country
    - ISO3 Code
    - Datetime (UTC)
    - Datetime (Local)
    - Price (EUR/MWhe)
    """
    try:
        df = pd.read_csv(filepath)
        
        # Standardize column names
        df = df.rename(columns={
            'Datetime (UTC)': 'timestamp',
            'ISO3 Code': 'iso3',
            'Price (EUR/MWhe)': 'price',
            'Country': 'country_name'
        })
        
        # Convert timestamp
        df['timestamp'] = pd.to_datetime(df['timestamp'])
        
        # Extract year
        df['year'] = df['timestamp'].dt.year
        
        # Map ISO3 to ISO2 (zone code)
        df['zone'] = df['iso3'].map(ISO3_TO_ISO2)
        
        # Drop rows where zone mapping failed
        before = len(df)
        df = df.dropna(subset=['zone'])
        after = len(df)
        
        if before > after:
            print(f"  ⚠️  Dropped {before - after} rows with unmapped ISO3 codes")
        
        # Keep only relevant columns
        df = df[['timestamp', 'zone', 'country_name', 'price', 'year']]
        
        return df
    
    except Exception as e:
        print(f"  ❌ Error loading {os.path.basename(filepath)}: {e}")
        return None


def load_all_pricing_data(pricing_dir, target_years=None):
    """
    Load all pricing CSV files from a directory.
    """
    print("=" * 70)
    print("LOADING PRICING DATA")
    print("=" * 70)
    
    # Find all CSV files
    csv_files = glob.glob(os.path.join(pricing_dir, '*.csv'))
    
    if not csv_files:
        print(f"No CSV files found in: {pricing_dir}")
        return None
    
    print(f"\n📁 Found {len(csv_files)} pricing files")
    
    all_pricing = []
    
    for i, filepath in enumerate(sorted(csv_files), 1):
        filename = os.path.basename(filepath)
        print(f"\n[{i}/{len(csv_files)}] Loading: {filename}")
        
        df = load_pricing_file(filepath)
        
        if df is not None:
            # Filter by year if specified
            if target_years:
                before = len(df)
                df = df[df['year'].isin(target_years)]
                after = len(df)
                print(f"  ✅ Loaded: {after:,} rows (filtered from {before:,} for years {target_years})")
            else:
                print(f"  ✅ Loaded: {len(df):,} rows")
            
            # Show date range
            print(f"     Zone: {df['zone'].iloc[0]}")
            print(f"     Date range: {df['timestamp'].min()} to {df['timestamp'].max()}")
            print(f"     Price range: €{df['price'].min():.2f} to €{df['price'].max():.2f}")
            
            # Check for negative prices
            neg_count = (df['price'] < 0).sum()
            if neg_count > 0:
                neg_pct = (neg_count / len(df)) * 100
                print(f"     ⚡ Negative prices: {neg_count} ({neg_pct:.2f}%)")
            
            all_pricing.append(df)
    
    
    # Combine all pricing data
    print(f"\n🔗 Combining {len(all_pricing)} pricing files...")
    combined = pd.concat(all_pricing, ignore_index=True)
    
    # Remove duplicates
    before = len(combined)
    combined = combined.drop_duplicates(subset=['timestamp', 'zone'])
    after = len(combined)
    
    if before > after:
        print(f"  ⚠️  Removed {before - after} duplicate rows")
    
    print(f"Combined pricing data: {len(combined):,} rows")
    print(f" Countries: {combined['zone'].nunique()}")
    print(f" Date range: {combined['timestamp'].min()} to {combined['timestamp'].max()}")
    
    return combined


def merge_carbon_and_pricing(carbon_df, pricing_df):
    """
    Merge carbon-free data with pricing data on timestamp and zone.
    """
    print("\n" + "=" * 70)
    print("MERGING CARBON-FREE AND PRICING DATA")
    print("=" * 70)
    
    print(f"\nBefore merge:")
    print(f"  Carbon-free data: {len(carbon_df):,} rows, {carbon_df['zone'].nunique()} countries")
    print(f"  Pricing data: {len(pricing_df):,} rows, {pricing_df['zone'].nunique()} countries")
    
    # Check which countries are in both datasets
    carbon_zones = set(carbon_df['zone'].unique())
    pricing_zones = set(pricing_df['zone'].unique())
    
    common_zones = carbon_zones & pricing_zones
    carbon_only = carbon_zones - pricing_zones
    pricing_only = pricing_zones - carbon_zones
    
    print(f"\n📊 Zone overlap:")
    print(f"  Common zones: {len(common_zones)} - {sorted(common_zones)}")
    
    if carbon_only:
        print(f"  ⚠️  Carbon data only: {sorted(carbon_only)}")
    if pricing_only:
        print(f"  ⚠️  Pricing data only: {sorted(pricing_only)}")
    
    # Merge
    print(f"\n🔗 Performing merge...")
    merged = carbon_df.merge(
        pricing_df[['timestamp', 'zone', 'price']],
        on=['timestamp', 'zone'],
        how='left'  # Keep all carbon-free data
    )
    
    # Analyze merge results
    total_rows = len(merged)
    matched_rows = merged['price'].notna().sum()
    match_rate = (matched_rows / total_rows) * 100
    
    print(f"Merge complete!")
    print(f"  Total rows: {total_rows:,}")
    print(f"  Rows with pricing: {matched_rows:,} ({match_rate:.1f}%)")
    print(f"  Rows without pricing: {total_rows - matched_rows:,} ({100 - match_rate:.1f}%)")
    
    # Breakdown by country
    print(f"\n📊 Match rate by country:")
    for zone in sorted(merged['zone'].unique()):
        zone_df = merged[merged['zone'] == zone]
        zone_matched = zone_df['price'].notna().sum()
        zone_rate = (zone_matched / len(zone_df)) * 100
        status = "✅" if zone_rate > 90 else "⚠️ " if zone_rate > 50 else "❌"
        print(f"  {status} {zone}: {zone_rate:.1f}% ({zone_matched:,}/{len(zone_df):,})")
    
    return merged


def analyze_merged_data(merged_df):
    """
    Perform analysis on the merged dataset.
    """
    print("\n" + "=" * 70)
    print("DATA ANALYSIS")
    print("=" * 70)
    
    # Overall statistics
    print(f"\n📊 Overall Statistics:")
    print(f"  Total rows: {len(merged_df):,}")
    print(f"  Countries: {merged_df['zone'].nunique()}")
    print(f"  Date range: {merged_df['timestamp'].min()} to {merged_df['timestamp'].max()}")
    
    # Price statistics
    price_data = merged_df['price'].dropna()
    print(f"\n💰 Price Statistics:")
    print(f"  Mean: €{price_data.mean():.2f}/MWh")
    print(f"  Median: €{price_data.median():.2f}/MWh")
    print(f"  Std Dev: €{price_data.std():.2f}/MWh")
    print(f"  Min: €{price_data.min():.2f}/MWh")
    print(f"  Max: €{price_data.max():.2f}/MWh")
    
    # Negative prices
    neg_count = (price_data < 0).sum()
    neg_pct = (neg_count / len(price_data)) * 100
    print(f"  Negative prices: {neg_count:,} ({neg_pct:.2f}%)")
    
    # Carbon-free statistics
    print(f"\n🌱 Carbon-Free Statistics:")
    print(f"  Mean: {merged_df['carbon_free_pct'].mean():.2f}%")
    print(f"  Median: {merged_df['carbon_free_pct'].median():.2f}%")
    print(f"  Std Dev: {merged_df['carbon_free_pct'].std():.2f}%")
    
    # Correlation
    complete_data = merged_df[['carbon_free_pct', 'price']].dropna()
    if len(complete_data) > 0:
        correlation = complete_data['carbon_free_pct'].corr(complete_data['price'])
        print(f"\n🔗 Correlation:")
        print(f"  Carbon-free % vs Price: {correlation:.3f}")
        
        if correlation < -0.2:
            print(f" Negative correlation: Higher carbon-free % → Lower prices")
        elif correlation > 0.2:
            print(f" Positive correlation: Higher carbon-free % → Higher prices")
        else:
            print(f"  ➡️  Weak correlation")


def save_results(merged_df, output_dir):
    """
    Save merged results and create summary reports.
    """
    print("\n" + "=" * 70)
    print("SAVING RESULTS")
    print("=" * 70)
    
    # Save full merged dataset
    output_path = os.path.join(output_dir, 'carbon_free_and_pricing_merged.csv')
    merged_df.to_csv(output_path, index=False)
    print(f"Full dataset saved to: {output_path}")
    
    # Save only rows with both carbon-free and pricing data
    complete_data = merged_df.dropna(subset=['carbon_free_pct', 'price'])
    complete_path = os.path.join(output_dir, 'complete_data_only.csv')
    complete_data.to_csv(complete_path, index=False)
    print(f"Complete data only: {complete_path}")
    print(f"   ({len(complete_data):,} rows with both carbon-free % and price)")
    
    # Create summary by country
    summary = merged_df.groupby('zone').agg({
        'timestamp': ['min', 'max', 'count'],
        'carbon_free_pct': ['mean', 'std'],
        'price': ['mean', 'std', 'count'],
        'country': 'first'
    }).round(2)
    
    summary_path = os.path.join(output_dir, 'country_summary.csv')
    summary.to_csv(summary_path)
    
    print(f"All files saved to: {output_dir}/")
def main():
    
    
    # Step 1: Load carbon-free data

    carbon_df = pd.read_csv(CARBON_FREE_DATA)
    carbon_df['timestamp'] = pd.to_datetime(carbon_df['timestamp'])
    print(f"Loaded carbon-free data: {len(carbon_df):,} rows, {carbon_df['zone'].nunique()} countries")
    # Step 2: Load pricing data
    pricing_df = load_all_pricing_data(PRICING_DIR, target_years=TARGET_YEARS)
    
    if pricing_df is None:
        print("Failed to load pricing data")
        return
    
    # Step 3: Merge datasets
    merged_df = merge_carbon_and_pricing(carbon_df, pricing_df)
    
    # Step 4: Analyze
    analyze_merged_data(merged_df)
    
    # Step 5: Save results
    save_results(merged_df, OUTPUT_DIR)

if __name__ == "__main__":
    main()
# Out:
# Loaded carbon-free data: 350,880 rows, 20 countries
# ======================================================================
# LOADING PRICING DATA
# ======================================================================
#
# 📁 Found 20 pricing files
#
# [1/20] Loading: Austria.csv
#   ✅ Loaded: 17,544 rows (filtered from 95,120 for years [2023, 2024])
#      Zone: AT
#      Date range: 2023-01-01 00:00:00 to 2024-12-31 23:00:00
#      Price range: €-270.42 to €711.69
#      ⚡ Negative prices: 335 (1.91%)
#
# [2/20] Loading: Belgium.csv
#   ✅ Loaded: 17,544 rows (filtered from 95,120 for years [2023, 2024])
#      Zone: BE
#      Date range: 2023-01-01 00:00:00 to 2024-12-31 23:00:00
#      Price range: €-140.00 to €565.46
#      ⚡ Negative prices: 625 (3.56%)
#
# [3/20] Loading: Czechia.csv
#   ✅ Loaded: 17,544 rows (filtered from 95,120 for years [2023, 2024])
#      Zone: CZ
#      Date range: 2023-01-01 00:00:00 to 2024-12-31 23:00:00
#      Price range: €-138.75 to €844.63
#      ⚡ Negative prices: 449 (2.56%)
#
# [4/20] Loading: Denmark.csv
#   ✅ Loaded: 17,544 rows (filtered from 95,120 for years [2023, 2024])
#      Zone: DK
#      Date range: 2023-01-01 00:00:00 to 2024-12-31 23:00:00
#      Price range: €-299.00 to €936.29
#      ⚡ Negative prices: 547 (3.12%)
#
# [5/20] Loading: Finland.csv
#   ✅ Loaded: 17,544 rows (filtered from 95,120 for years [2023, 2024])
#      Zone: FI
#      Date range: 2023-01-01 00:00:00 to 2024-12-31 23:00:00
#      Price range: €-500.00 to €1896.00
#      ⚡ Negative prices: 1192 (6.79%)
#
# [6/20] Loading: France.csv
#   ✅ Loaded: 17,544 rows (filtered from 95,120 for years [2023, 2024])
#      Zone: FR
#      Date range: 2023-01-01 00:00:00 to 2024-12-31 23:00:00
#      Price range: €-134.94 to €284.21
#      ⚡ Negative prices: 499 (2.84%)
#
# [7/20] Loading: Germany.csv
#   ✅ Loaded: 17,544 rows (filtered from 95,120 for years [2023, 2024])
#      Zone: DE
#      Date range: 2023-01-01 00:00:00 to 2024-12-31 23:00:00
#      Price range: €-316.40 to €808.87
#      ⚡ Negative prices: 580 (3.31%)
#
# [8/20] Loading: Greece.csv
#   ✅ Loaded: 17,544 rows (filtered from 95,120 for years [2023, 2024])
#      Zone: GR
#      Date range: 2023-01-01 00:00:00 to 2024-12-31 23:00:00
#      Price range: €-1.02 to €942.00
#      ⚡ Negative prices: 11 (0.06%)
#
# [9/20] Loading: Hungary.csv
#   ✅ Loaded: 17,544 rows (filtered from 95,120 for years [2023, 2024])
#      Zone: HU
#      Date range: 2023-01-01 00:00:00 to 2024-12-31 23:00:00
#      Price range: €-500.00 to €999.01
#      ⚡ Negative prices: 336 (1.92%)
#
# [10/20] Loading: Ireland.csv
#   ✅ Loaded: 17,544 rows (filtered from 62,257 for years [2023, 2024])
#      Zone: IE
#      Date range: 2023-01-01 00:00:00 to 2024-12-31 23:00:00
#      Price range: €-10.19 to €499.99
#      ⚡ Negative prices: 88 (0.50%)
#
# [11/20] Loading: Italy.csv
#   ✅ Loaded: 17,544 rows (filtered from 95,120 for years [2023, 2024])
#      Zone: IT
#      Date range: 2023-01-01 00:00:00 to 2024-12-31 23:00:00
#      Price range: €0.10 to €295.00
#
# [12/20] Loading: Netherlands.csv
#   ✅ Loaded: 17,544 rows (filtered from 95,120 for years [2023, 2024])
#      Zone: NL
#      Date range: 2023-01-01 00:00:00 to 2024-12-31 23:00:00
#      Price range: €-500.00 to €872.96
#      ⚡ Negative prices: 773 (4.41%)
#
# [13/20] Loading: Norway.csv
#   ✅ Loaded: 17,544 rows (filtered from 95,120 for years [2023, 2024])
#      Zone: NO
#      Date range: 2023-01-01 00:00:00 to 2024-12-31 23:00:00
#      Price range: €-32.20 to €404.98
#      ⚡ Negative prices: 269 (1.53%)
#
# [14/20] Loading: Poland.csv
#   ✅ Loaded: 17,544 rows (filtered from 95,120 for years [2023, 2024])
#      Zone: PL
#      Date range: 2023-01-01 00:00:00 to 2024-12-31 23:00:00
#      Price range: €-61.64 to €630.19
#      ⚡ Negative prices: 240 (1.37%)
#
# [15/20] Loading: Portugal.csv
#   ✅ Loaded: 17,544 rows (filtered from 95,120 for years [2023, 2024])
#      Zone: PT
#      Date range: 2023-01-01 00:00:00 to 2024-12-31 23:00:00
#      Price range: €-2.00 to €220.00
#      ⚡ Negative prices: 196 (1.12%)
#
# [16/20] Loading: Romania.csv
#   ✅ Loaded: 17,544 rows (filtered from 95,120 for years [2023, 2024])
#      Zone: RO
#      Date range: 2023-01-01 00:00:00 to 2024-12-31 23:00:00
#      Price range: €-106.36 to €1021.61
#      ⚡ Negative prices: 117 (0.67%)
#
# [17/20] Loading: Spain.csv
#   ✅ Loaded: 17,544 rows (filtered from 95,120 for years [2023, 2024])
#      Zone: ES
#      Date range: 2023-01-01 00:00:00 to 2024-12-31 23:00:00
#      Price range: €-2.00 to €220.00
#      ⚡ Negative prices: 247 (1.41%)
#
# [18/20] Loading: Sweden.csv
#   ✅ Loaded: 17,544 rows (filtered from 95,120 for years [2023, 2024])
#      Zone: SE
#      Date range: 2023-01-01 00:00:00 to 2024-12-31 23:00:00
#      Price range: €-60.04 to €560.08
#      ⚡ Negative prices: 980 (5.59%)
#
# [19/20] Loading: Switzerland.csv
#   ✅ Loaded: 17,544 rows (filtered from 94,224 for years [2023, 2024])
#      Zone: CH
#      Date range: 2023-01-01 00:00:00 to 2024-12-31 23:00:00
#      Price range: €-427.51 to €310.64
#      ⚡ Negative prices: 368 (2.10%)
#
# [20/20] Loading: United Kingdom.csv
#   ✅ Loaded: 17,544 rows (filtered from 81,961 for years [2023, 2024])
#      Zone: GB
#      Date range: 2023-01-01 00:00:00 to 2024-12-31 23:00:00
#      Price range: €-60.19 to €583.16
#      ⚡ Negative prices: 253 (1.44%)
#
# 🔗 Combining 20 pricing files...
# Combined pricing data: 350,880 rows
#  Countries: 20
#  Date range: 2023-01-01 00:00:00 to 2024-12-31 23:00:00
#
# ======================================================================
# MERGING CARBON-FREE AND PRICING DATA
# ======================================================================
#
# Before merge:
#   Carbon-free data: 350,880 rows, 20 countries
#   Pricing data: 350,880 rows, 20 countries
#
# 📊 Zone overlap:
#   Common zones: 20 - ['AT', 'BE', 'CH', 'CZ', 'DE', 'DK', 'ES', 'FI', 'FR', 'GB', 'GR', 'HU', 'IE', 'IT', 'NL', 'NO', 'PL', 'PT', 'RO', 'SE']
#
# 🔗 Performing merge...
# Merge complete!
#   Total rows: 350,880
#   Rows with pricing: 350,880 (100.0%)
#   Rows without pricing: 0 (0.0%)
#
# 📊 Match rate by country:
#   ✅ AT: 100.0% (17,544/17,544)
#   ✅ BE: 100.0% (17,544/17,544)
#   ✅ CH: 100.0% (17,544/17,544)
#   ✅ CZ: 100.0% (17,544/17,544)
#   ✅ DE: 100.0% (17,544/17,544)
#   ✅ DK: 100.0% (17,544/17,544)
#   ✅ ES: 100.0% (17,544/17,544)
#   ✅ FI: 100.0% (17,544/17,544)
#   ✅ FR: 100.0% (17,544/17,544)
#   ✅ GB: 100.0% (17,544/17,544)
#   ✅ GR: 100.0% (17,544/17,544)
#   ✅ HU: 100.0% (17,544/17,544)
#   ✅ IE: 100.0% (17,544/17,544)
#   ✅ IT: 100.0% (17,544/17,544)
#   ✅ NL: 100.0% (17,544/17,544)
#   ✅ NO: 100.0% (17,544/17,544)
#   ✅ PL: 100.0% (17,544/17,544)
#   ✅ PT: 100.0% (17,544/17,544)
#   ✅ RO: 100.0% (17,544/17,544)
#   ✅ SE: 100.0% (17,544/17,544)
#
# ======================================================================
# DATA ANALYSIS
# ======================================================================
#
# 📊 Overall Statistics:
#   Total rows: 350,880
#   Countries: 20
#   Date range: 2023-01-01 00:00:00 to 2024-12-31 23:00:00
#
# 💰 Price Statistics:
#   Mean: €86.82/MWh
#   Median: €88.59/MWh
#   Std Dev: €53.71/MWh
#   Min: €-500.00/MWh
#   Max: €1896.00/MWh
#   Negative prices: 8,105 (2.31%)
#
# 🌱 Carbon-Free Statistics:
#   Mean: 72.58%
#   Median: 76.64%
#   Std Dev: 22.67%
#
# 🔗 Correlation:
#   Carbon-free % vs Price: -0.485
#  Negative correlation: Higher carbon-free % → Lower prices
#
# ======================================================================
# SAVING RESULTS
# ======================================================================
# Full dataset saved to: /Users/annie_lok_yan_wong/Downloads/european_wholesale_electricity_price_data_hourly/For_merging/final_merged/carbon_free_and_pricing_merged.csv
# Complete data only: /Users/annie_lok_yan_wong/Downloads/european_wholesale_electricity_price_data_hourly/For_merging/final_merged/complete_data_only.csv
#    (350,880 rows with both carbon-free % and price)
# All files saved to: /Users/annie_lok_yan_wong/Downloads/european_wholesale_electricity_price_data_hourly/For_merging/final_merged/

# %%
DATA_FILE = '/Users/annie_lok_yan_wong/Downloads/european_wholesale_electricity_price_data_hourly/For_merging/final_merged/complete_data_only.csv'

# %%
df = pd.read_csv(DATA_FILE)
print(df.head())
# Out:
#              timestamp zone  country  carbon_free_pct  renewable_pct  \
# 0  2023-01-01 00:00:00   AT  Austria            83.29          70.09
# 1  2023-01-01 01:00:00   AT  Austria            82.78          69.40
# 2  2023-01-01 02:00:00   AT  Austria            82.37          68.71
# 3  2023-01-01 03:00:00   AT  Austria            81.61          67.24
# 4  2023-01-01 04:00:00   AT  Austria            81.20          66.00
#
#    carbon_intensity_direct  carbon_intensity_lifecycle  is_estimated  year  \
# 0                   158.86                      196.54         False  2023
# 1                   164.07                      201.87         False  2023
# 2                   167.60                      206.23         False  2023
# 3                   173.77                      213.41         False  2023
# 4                   177.88                      218.07         False  2023
#
#                                source_file  price
# 0  snapshots_2025-07-03_AT-2023-hourly.csv  -7.15
# 1  snapshots_2025-07-03_AT-2023-hourly.csv  -7.32
# 2  snapshots_2025-07-03_AT-2023-hourly.csv  -9.49
# 3  snapshots_2025-07-03_AT-2023-hourly.csv -11.47
# 4  snapshots_2025-07-03_AT-2023-hourly.csv  -1.44

# %%
import pandas as pd

df['timestamp'] = pd.to_datetime(df['timestamp'])


df['hour'] = df['timestamp'].dt.hour

hourly_avg = df.groupby(['year', 'hour']).agg({
    'price': 'mean',
    'carbon_free_pct': 'mean'
}).reset_index()

hourly_avg.columns = ['year', 'hour', 'avg_price', 'avg_carbon_free_pct']

print(hourly_avg)

hourly_2023 = hourly_avg[hourly_avg['year'] == 2023]
hourly_2024 = hourly_avg[hourly_avg['year'] == 2024]


print(hourly_2023)
print(hourly_2024)
# Out:
#     year  hour   avg_price  avg_carbon_free_pct
# 0   2023     0   83.110585            65.443371
# 1   2023     1   80.202653            65.518263
# 2   2023     2   78.581741            65.549703
# 3   2023     3   81.712102            65.331976
# 4   2023     4   91.812519            65.167965
# 5   2023     5  104.881183            65.730796
# 6   2023     6  110.761566            66.971624
# 7   2023     7  107.639033            68.587244
# 8   2023     8   98.816591            70.423947
# 9   2023     9   91.098140            71.814973
# 10  2023    10   85.541589            72.605054
# 11  2023    11   80.655758            72.936796
# 12  2023    12   79.029695            72.727434
# 13  2023    13   83.338651            71.821944
# 14  2023    14   91.370701            70.158416
# 15  2023    15  104.216591            68.014015
# 16  2023    16  119.913853            66.051209
# 17  2023    17  133.516630            64.842553
# 18  2023    18  132.785534            64.187560
# 19  2023    19  121.174861            63.798807
# 20  2023    20  109.618878            63.494135
# 21  2023    21  100.095869            63.512382
# 22  2023    22   92.869678            64.361771
# 23  2023    23   87.257900            65.162732
# 24  2024     0   67.708348            68.605940
# 25  2024     1   65.640008            68.662776
# 26  2024     2   64.466438            68.718796
# 27  2024     3   66.835974            68.535656
# 28  2024     4   75.845866            68.342758
# 29  2024     5   86.524552            68.802973
# 30  2024     6   90.120783            70.073825
# 31  2024     7   84.443539            71.929941
# 32  2024     8   74.033097            73.783484
# 33  2024     9   65.607457            75.165254
# 34  2024    10   60.097293            75.883539
# 35  2024    11   56.921516            76.085632
# 36  2024    12   57.044912            75.730744
# 37  2024    13   62.655767            74.594516
# 38  2024    14   73.575317            72.645125
# 39  2024    15   89.789683            70.296286
# 40  2024    16  109.257316            68.116308
# 41  2024    17  125.510990            66.659254
# 42  2024    18  124.220167            65.872628
# 43  2024    19  107.691546            65.613836
# 44  2024    20   92.824500            65.676217
# 45  2024    21   82.990506            66.210045
# 46  2024    22   76.520608            67.242927
# 47  2024    23   71.415788            68.215408
#     year  hour   avg_price  avg_carbon_free_pct
# 0   2023     0   83.110585            65.443371
# 1   2023     1   80.202653            65.518263
# 2   2023     2   78.581741            65.549703
# 3   2023     3   81.712102            65.331976
# 4   2023     4   91.812519            65.167965
# 5   2023     5  104.881183            65.730796
# 6   2023     6  110.761566            66.971624
# 7   2023     7  107.639033            68.587244
# 8   2023     8   98.816591            70.423947
# 9   2023     9   91.098140            71.814973
# 10  2023    10   85.541589            72.605054
# 11  2023    11   80.655758            72.936796
# 12  2023    12   79.029695            72.727434
# 13  2023    13   83.338651            71.821944
# 14  2023    14   91.370701            70.158416
# 15  2023    15  104.216591            68.014015
# 16  2023    16  119.913853            66.051209
# 17  2023    17  133.516630            64.842553
# 18  2023    18  132.785534            64.187560
# 19  2023    19  121.174861            63.798807
# 20  2023    20  109.618878            63.494135
# 21  2023    21  100.095869            63.512382
# 22  2023    22   92.869678            64.361771
# 23  2023    23   87.257900            65.162732
#     year  hour   avg_price  avg_carbon_free_pct
# 24  2024     0   67.708348            68.605940
# 25  2024     1   65.640008            68.662776
# 26  2024     2   64.466438            68.718796
# 27  2024     3   66.835974            68.535656
# 28  2024     4   75.845866            68.342758
# 29  2024     5   86.524552            68.802973
# 30  2024     6   90.120783            70.073825
# 31  2024     7   84.443539            71.929941
# 32  2024     8   74.033097            73.783484
# 33  2024     9   65.607457            75.165254
# 34  2024    10   60.097293            75.883539
# 35  2024    11   56.921516            76.085632
# 36  2024    12   57.044912            75.730744
# 37  2024    13   62.655767            74.594516
# 38  2024    14   73.575317            72.645125
# 39  2024    15   89.789683            70.296286
# 40  2024    16  109.257316            68.116308
# 41  2024    17  125.510990            66.659254
# 42  2024    18  124.220167            65.872628
# 43  2024    19  107.691546            65.613836
# 44  2024    20   92.824500            65.676217
# 45  2024    21   82.990506            66.210045
# 46  2024    22   76.520608            67.242927
# 47  2024    23   71.415788            68.215408

# %%
hourly_avg.to_csv('/Users/annie_lok_yan_wong/Downloads/european_wholesale_electricity_price_data_hourly/For_merging/final_merged/hourly_average_price_and_cfe.csv', index=False)
