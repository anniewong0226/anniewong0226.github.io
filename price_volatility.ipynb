# %%
import pandas as pd

countries_to_keep = [
    'NLD', 'DEU', 'FRA', 'ESP', 'ITA', 'GBR', 'BEL', 'POL', 'AUT', 
    'SWE', 'NOR', 'DNK', 'FIN', 'PRT', 'GRC', 'CZE', 'ROU', 'IRL', 'HUN'
]

df = pd.read_csv('/Users/annie_lok_yan_wong/Downloads/european_wholesale_electricity_price_data_hourly/all_countries.csv')
df.columns  
countries = df['Country'].unique()
print(countries)
# Out:
# ['Austria' 'Belgium' 'Czechia' 'Denmark' 'Estonia' 'Finland' 'France'
#  'Germany' 'Greece' 'Hungary' 'Italy' 'Latvia' 'Lithuania' 'Luxembourg'
#  'Netherlands' 'Norway' 'Poland' 'Portugal' 'Romania' 'Slovakia'
#  'Slovenia' 'Spain' 'Sweden' 'Switzerland' 'United Kingdom' 'Bulgaria'
#  'Serbia' 'Croatia' 'Ireland' 'Montenegro' 'North Macedonia']

# %%
filtered_df = df[df['ISO3 Code'].isin(countries_to_keep)]
countries = filtered_df['Country'].unique()
print(countries)
# Out:
# ['Austria' 'Belgium' 'Czechia' 'Denmark' 'Finland' 'France' 'Germany'
#  'Greece' 'Hungary' 'Italy' 'Netherlands' 'Norway' 'Poland' 'Portugal'
#  'Romania' 'Spain' 'Sweden' 'United Kingdom' 'Ireland']

# %%
filtered_df.head()
# Out:
#    Country ISO3 Code       Datetime (UTC)     Datetime (Local)  \
# 0  Austria       AUT  2015-01-01 00:00:00  2015-01-01 01:00:00
# 1  Belgium       BEL  2015-01-01 00:00:00  2015-01-01 01:00:00
# 2  Czechia       CZE  2015-01-01 00:00:00  2015-01-01 01:00:00
# 3  Denmark       DNK  2015-01-01 00:00:00  2015-01-01 01:00:00
# 5  Finland       FIN  2015-01-01 00:00:00  2015-01-01 02:00:00
#
#    Price (EUR/MWhe)
# 0             22.34
# 1             36.56
# 2             24.20
# 3             18.29
# 5             23.37
